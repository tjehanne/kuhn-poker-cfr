# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (2.7.1+cu118)
# Requirement already satisfied: torchvision in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (0.22.1+cu118)
# Requirement already satisfied: torchaudio in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (2.7.1+cu118)
# Requirement already satisfied: filelock in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torchvision) (2.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jules\documents\5a\ia2\tumor-detection\.venv\lib\site-packages (from jinja2->torch) (3.0.3)
# 2.7.1+cu118
# True

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[0]  # tumor-detection
sys.path.insert(0, str(PROJECT_ROOT))

import matplotlib.pyplot as plt
from src.datasets.mri_dataset import MRIDataset

# %%
from pathlib import Path

DATA_DIR = PROJECT_ROOT / "data" / "raw" / "Training"

dataset = MRIDataset(DATA_DIR)

print(f"Nombre d'images : {len(dataset)}")
# Out:
# Nombre d'images : 5712

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

for i, ax in enumerate(axes.flatten()):
    img, label = dataset[i]
    ax.imshow(img)
    ax.set_title(f"Label: {label}")
    ax.axis("off")

plt.show()
